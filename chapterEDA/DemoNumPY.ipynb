# %%
import numpy
num_array = numpy.array([10 , 20 , 30 , 40])
print(num_array)
print(type(num_array))
print(num_array.dtype) #using dtype we are able to see data type of array collection
# Out:
# [10 20 30 40]
# <class 'numpy.ndarray'>
# int64

# %%
numbers = [10, 20 ,30 ,40 , "NAme" , 3.5]
print(numbers)
print(type(numbers))
# Out:
# [10, 20, 30, 40, 'NAme', 3.5]
# <class 'list'>
