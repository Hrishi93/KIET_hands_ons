# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('student_clustering.csv')

# %%
#df.head()
#df.columns
df.shape
# Out:
# (200, 2)

# %%
#Ploted the data points
plt.scatter(df['cgpa'] , df['iq'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.show()

# %%
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters=i)
    km.fit(df)
    wcss.append(km.inertia_)

wcss
# Out:
# [29957.898288,
#  4184.14127,
#  2503.397581,
#  681.96966,
#  530.4298616986188,
#  395.9605877691832,
#  387.49365995806056,
#  260.1227011760185,
#  218.16001016422535,
#  174.83726498565608]

# %%
#Plotting the data points
plt.plot(range(1, 11), wcss , marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
X = df.iloc[:, :].values #converting dataframe to numpy array
km = KMeans(n_clusters= 4)
y_km = km.fit_predict(X)

# %%
print(y_km)
# Out:
# [0 3 2 2 3 3 2 1 3 2 0 3 2 0 3 2 3 2 3 3 2 0 2 0 0 2 0 1 2 3 1 3 1 3 2 2 1
#  3 0 3 0 2 2 0 1 1 2 3 1 3 0 0 1 2 1 3 3 1 3 1 3 2 2 1 0 1 2 0 3 2 3 1 2 0
#  3 1 3 1 0 2 2 1 3 0 1 0 1 3 1 3 1 1 2 0 2 2 1 2 0 1 3 0 0 1 0 0 2 0 1 1 2
#  1 3 3 2 1 2 3 1 0 0 3 2 1 2 0 2 3 0 2 2 3 0 0 3 1 3 0 2 2 2 0 3 0 0 1 0 1
#  3 0 1 0 1 1 0 2 3 1 3 2 0 1 3 2 1 0 3 0 0 1 1 3 1 0 0 2 1 3 0 1 1 3 3 3 2
#  0 2 2 1 3 2 2 0 0 2 0 1 3 3 1]

# %%
#print(y_km == 0)
#X[y_km == 0, 0] #cgpa of cluster 0
X[y_km == 1 , 1] #iq of cluster 1
# Out:
# array([115., 119., 117., 118., 118., 116., 116., 119., 116., 115., 115.,
#        117., 118., 113., 116., 118., 117., 121., 116., 117., 117., 117.,
#        114., 118., 118., 119., 118., 118., 117., 118., 117., 119., 118.,
#        118., 117., 117., 117., 116., 118., 119., 117., 119., 120., 117.,
#        115., 115., 117., 116., 118., 117.])

# %%
#Dipslaying the cluster 0
plt.scatter(X[y_km == 0, 0], X[y_km == 0, 1])
