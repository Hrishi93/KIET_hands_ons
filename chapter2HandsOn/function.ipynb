# %%
num1 = 10
num2 = 20
sum = num1 + num2
print(sum)
# Out:
# 30

# %%
#block of code that excecute when we call
def addition():
    num1 = 10
    num2 = 20
    sum = num1 + num2
    print(sum)

# %%
#we are passing var as parameter
def add(num1 , num2 ):
    sum = num1 + num2 
    print(sum)

# %%
addition() #function call
#Pass the orguments
add(10 , 30) #function call with orgument #int
add(10.20 , 20.30)#float
add(20 , 55.5) # int float # float
add("Hrishi" , "Mahure")#string
#add("Hrishi" , 30) #string  30
# Out:
# 30
# 40
# 30.5
# 75.5
# HrishiMahure

# %%
def welcome_msg():
    print("welcome in KIET college")

# %%
welcome_msg()
# Out:
# welcome in KIET college

# %%
#def welcome(name1 , name2, name3):
def welcome(*names):
    print("Welcome ", names)

# %%
welcome("Hrishi")
welcome("Hrishi" , "Shyam")
# Out:
# Welcome  ('Hrishi',)
# Welcome  ('Hrishi', 'Shyam')

# %%
#return type
#function is not returning any value ; void method

def sub(num1 , num2):
    ans = num1-num2;
    print(ans)


sub(20 , 10)
# Out:
# 10

# %%
#if function return value 
#return fun 
#return keyword

def mul(num1 , num2):
    ans = num1*num2
    return ans

mul(10, 20)
# Out:
# 200

# %%
#WAP it will take num1 and num2 as argument of function 
#and will return addition , multiflication , subtraction

# %%
#define a function
def addition(num1 , num2):
    answer = num1 + num2
    return "addition" , answer

# %%
number1 = int(input("Enter First Number"))
number2 = int(input("Enter Second Number"))

#function Call
addition(number1 , number2)
# Out:
# ('addition', 99)
