# %%
#WAP find out the person is voter or not

age = 19

if age> 100:
    print("Age exceeds the limit")
elif age<0:
    print("Invalid age")
elif age>=18:
    print("Person is eligible to vote")
else:
    print("Person is not eligible to vote")
# Out:
# Person is eligible to vote
