# %%
name = "Hrishikesh"
password = "Hrishi@1234"

full_name ="hrishikesh jiwan mahure"
full_name2 ="Ram@Kumar@sharma"

#isaplha
print(name.isalpha())  #alphabet
print(name.isnumeric()) #only number
print(name.isalnum()) #alhabet or number or combine


#split
split_name = full_name.split()
print(split_name)

split_name2 = full_name2.split('@')
print(split_name2) 

#upper
upper_name = full_name.upper()
print(upper_name)

#capital
capital_name = full_name.capitalize()
print(capital_name)

#title 
title_FN = full_name.title()
print(title_FN)

print(len(name))
#trim
trim_name = name.strip()
print(len(trim_name))

#replace
replace_name = name.replace('i' , '@')
print(replace_name)

print("--------------------")
#slice
print(name[0:6])  #Hrishi
print(name[0:3]) #Hri
print(password[7:]) #1234
print(password[7:9]) #12

#Edunet Foundation

#lenth
print(len(name)) 
print(len(password))

#Indexing
print(name[0]) #H
print(password[6]) #@
print(password[10]) #4

print(password[-1])
print(password[-11])
# Out:
# True
# False
# True
# ['hrishikesh', 'jiwan', 'mahure']
# ['Ram', 'Kumar', 'sharma']
# HRISHIKESH JIWAN MAHURE
# Hrishikesh jiwan mahure
# Hrishikesh Jiwan Mahure
# 10
# 10
# Hr@sh@kesh
# --------------------
# Hrishi
# Hri
# 1234
# 12
# 10
# 11
# H
# @
# 4
# 4
# H

# %%
full_name = "Edunet Foundation"

first_name = full_name[0:6]
last_name = full_name[7:]
print(first_name)
print(last_name)
# Out:
# Edunet
# Foundation

# %%
phrase = "Data Science is awesome!"

print(phrase.replace("awesome" , "amazing"))
# Out:
# Data Science is amazing!

# %%
url = "https://www.example.com"
print(url[8:])
# Out:
# www.example.com
