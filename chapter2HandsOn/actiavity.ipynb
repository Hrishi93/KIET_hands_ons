# %%
first_quarter = 50000
second_quarter = 75000
third_quarter = 60000
fourth_quarter = 65000

total_profit =  first_quarter + second_quarter + third_quarter + fourth_quarter
print("Year Profit :" , total_profit)
# Out:
# Year Profit : 250000

# %%
number = 200; #constent value
duplicate_number = number  #value i.e available in number varaible
print(duplicate_number)
# Out:
# 200
